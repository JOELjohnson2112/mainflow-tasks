# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data=pd.read_csv('diabetes_data.csv')

# %%
df.head()
# Out:
#    PatientID  Age  Gender  Ethnicity  SocioeconomicStatus  EducationLevel  \
# 0       6000   44       0          1                    2               1
# 1       6001   51       1          0                    1               2
# 2       6002   89       1          0                    1               3
# 3       6003   21       1          1                    1               2
# 4       6004   27       1          0                    1               3
#
#          BMI  Smoking  AlcoholConsumption  PhysicalActivity  ...  \
# 0  32.985284        1            4.499365          2.443385  ...
# 1  39.916764        0            1.578919          8.301264  ...
# 2  19.782251        0            1.177301          6.103395  ...
# 3  32.376881        1            1.714621          8.645465  ...
# 4  16.808600        0           15.462549          4.629383  ...
#
#    TinglingHandsFeet  QualityOfLifeScore  HeavyMetalsExposure  \
# 0                  1           73.765109                    0
# ...

# %%
df.tail()
# Out:
#       PatientID  Age  Gender  Ethnicity  SocioeconomicStatus  EducationLevel  \
# 1874       7874   37       0          0                    2               2
# 1875       7875   80       1          0                    2               2
# 1876       7876   38       1          0                    0               2
# 1877       7877   43       0          1                    2               0
# 1878       7878   85       1          0                    2               2
#
#             BMI  Smoking  AlcoholConsumption  PhysicalActivity  ...  \
# 1874  20.811137        0           10.946207          3.217636  ...
# 1875  27.694312        0           16.067905          7.107335  ...
# 1876  35.640824        0            4.865124          9.881212  ...
# 1877  32.423016        0            6.362936          4.750079  ...
# 1878  33.145119        0           13.854861          5.434137  ...
#
#       TinglingHandsFeet  QualityOfLifeScore  HeavyMetalsExposure  \
# ...

# %%
df.columns.values
# Out:
# array(['PatientID', 'Age', 'Gender', 'Ethnicity', 'SocioeconomicStatus',
#        'EducationLevel', 'BMI', 'Smoking', 'AlcoholConsumption',
#        'PhysicalActivity', 'DietQuality', 'SleepQuality',
#        'FamilyHistoryDiabetes', 'GestationalDiabetes',
#        'PolycysticOvarySyndrome', 'PreviousPreDiabetes', 'Hypertension',
#        'SystolicBP', 'DiastolicBP', 'FastingBloodSugar', 'HbA1c',
#        'SerumCreatinine', 'BUNLevels', 'CholesterolTotal',
#        'CholesterolLDL', 'CholesterolHDL', 'CholesterolTriglycerides',
#        'AntihypertensiveMedications', 'Statins',
#        'AntidiabeticMedications', 'FrequentUrination', 'ExcessiveThirst',
#        'UnexplainedWeightLoss', 'FatigueLevels', 'BlurredVision',
#        'SlowHealingSores', 'TinglingHandsFeet', 'QualityOfLifeScore',
#        'HeavyMetalsExposure', 'OccupationalExposureChemicals',
#        'WaterQuality', 'MedicalCheckupsFrequency', 'MedicationAdherence',
# ...

# %%
df.isna().sum()
# Out:
# PatientID                        0
# Age                              0
# Gender                           0
# Ethnicity                        0
# SocioeconomicStatus              0
# EducationLevel                   0
# BMI                              0
# Smoking                          0
# AlcoholConsumption               0
# PhysicalActivity                 0
# DietQuality                      0
# SleepQuality                     0
# FamilyHistoryDiabetes            0
# GestationalDiabetes              0
# PolycysticOvarySyndrome          0
# PreviousPreDiabetes              0
# Hypertension                     0
# SystolicBP                       0
# DiastolicBP                      0
# FastingBloodSugar                0
# HbA1c                            0
# SerumCreatinine                  0
# BUNLevels                        0
# CholesterolTotal                 0
# CholesterolLDL                   0
# CholesterolHDL                   0
# CholesterolTriglycerides         0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1879 entries, 0 to 1878
# Data columns (total 46 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   PatientID                      1879 non-null   int64
#  1   Age                            1879 non-null   int64
#  2   Gender                         1879 non-null   int64
#  3   Ethnicity                      1879 non-null   int64
#  4   SocioeconomicStatus            1879 non-null   int64
#  5   EducationLevel                 1879 non-null   int64
#  6   BMI                            1879 non-null   float64
#  7   Smoking                        1879 non-null   int64
#  8   AlcoholConsumption             1879 non-null   float64
#  9   PhysicalActivity               1879 non-null   float64
#  10  DietQuality                    1879 non-null   float64
#  11  SleepQuality                   1879 non-null   float64
# ...

# %%
df.hist(bins=50,grid=False,figsize=(20,15));

# %%
df.describe()
# Out:
#          PatientID          Age       Gender    Ethnicity  \
# count  1879.000000  1879.000000  1879.000000  1879.000000
# mean   6939.000000    55.043108     0.487493     0.755721
# std     542.564896    20.515839     0.499977     1.047558
# min    6000.000000    20.000000     0.000000     0.000000
# 25%    6469.500000    38.000000     0.000000     0.000000
# 50%    6939.000000    55.000000     0.000000     0.000000
# 75%    7408.500000    73.000000     1.000000     1.000000
# max    7878.000000    90.000000     1.000000     3.000000
#
#        SocioeconomicStatus  EducationLevel          BMI      Smoking  \
# count          1879.000000     1879.000000  1879.000000  1879.000000
# mean              0.992017        1.699308    27.687601     0.281533
# std               0.764940        0.885665     7.190975     0.449866
# min               0.000000        0.000000    15.025898     0.000000
# 25%               0.000000        1.000000    21.469981     0.000000
# ...

# %%
#1 What factors are most strongly correlated with a diabetes diagnosis?
data_numeric = data.select_dtypes(include=['number'])
plt.figure(figsize=(10, 8))
correlation = data_numeric.corr()['Diagnosis'].sort_values(ascending=False)
top_corr = correlation[1:11]  # Top 10 correlated factors excluding 'Diagnosis' itself

sns.barplot(x=top_corr.values, y=top_corr.index, palette='coolwarm')
plt.title('Top 10 Correlations with Diabetes Diagnosis', fontsize=14)
plt.xlabel('Correlation Coefficient', fontsize=12)
plt.ylabel('Features', fontsize=12)
plt.show()

# %% [raw]
# Correlation Heatmap: Identifies the top features correlated with Diagnosis

# %%
#2 How do BMI and physical activity level influence diabetes diagnosis and associated risk factors?

plt.figure(figsize=(12, 6))
sns.scatterplot(x='BMI', y='FastingBloodSugar', hue='Diagnosis', data=data_numeric, palette='viridis', alpha=0.7)
plt.title('BMI vs. Fasting Blood Sugar by Diagnosis', fontsize=14)
plt.xlabel('BMI', fontsize=12)
plt.ylabel('Fasting Blood Sugar', fontsize=12)
plt.legend(title='Diagnosis', labels=['Non-Diabetic', 'Diabetic'])
plt.show()

plt.figure(figsize=(12, 6))
sns.scatterplot(x='PhysicalActivity', y='HbA1c', hue='Diagnosis', data=data_numeric, palette='coolwarm', alpha=0.7)
plt.title('Physical Activity vs. HbA1c by Diagnosis', fontsize=14)
plt.xlabel('Physical Activity', fontsize=12)
plt.ylabel('HbA1c', fontsize=12)
plt.legend(title='Diagnosis', labels=['Non-Diabetic', 'Diabetic'])
plt.show()

# %% [raw]
# BMI and Physical Activity Influence: Scatter plots with regression lines to show relationships with diabetes indicators.

# %%
#3 Do socioeconomic status and education level affect medication adherence and health literacy?

plt.figure(figsize=(12, 6))
sns.boxplot(x='Diagnosis', y='MedicationAdherence', hue='SocioeconomicStatus', data=data_numeric, palette='pastel')
plt.title('Medication Adherence by Diagnosis and Socioeconomic Status', fontsize=14)
plt.xlabel('Diagnosis', fontsize=12)
plt.ylabel('Medication Adherence', fontsize=12)
plt.legend(title='Socioeconomic Status', bbox_to_anchor=(1.05, 1))
plt.show()

plt.figure(figsize=(12, 6))
sns.boxplot(x='Diagnosis', y='HealthLiteracy', hue='EducationLevel', data=data_numeric, palette='muted')
plt.title('Health Literacy by Diagnosis and Education Level', fontsize=14)
plt.xlabel('Diagnosis', fontsize=12)
plt.ylabel('Health Literacy', fontsize=12)
plt.legend(title='Education Level', bbox_to_anchor=(1.05, 1))
plt.show()

# %% [raw]
# Socioeconomic and Education Impact: Box plots to compare groups by medication adherence and health literacy.

# %%
#4 What role do lifestyle factors play in predicting diabetes or related complications?
lifestyle_factors = ['Smoking', 'AlcoholConsumption', 'DietQuality', 'SleepQuality']
sns.pairplot(data_numeric, vars=lifestyle_factors, hue='Diagnosis', palette='coolwarm', diag_kind='kde')
plt.suptitle('Pairwise Relationships of Lifestyle Factors', y=1.02, fontsize=16)
plt.show()

# %% [raw]
# Lifestyle Factors: Pairwise scatter plots and density plots to explore relationships between lifestyle factors and Diagnosis.
